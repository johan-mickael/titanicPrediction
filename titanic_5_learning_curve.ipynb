# %%
# %run titanic_4_survival_prediction.ipynb

from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression

import matplotlib.pyplot as plt
# Out:
# Note: you may need to restart the kernel to use updated packages.
# snowflake-connector-python has been installed.
# /tmp/ipykernel_15558/2994179729.py:14: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data = pd.read_sql(query, conn)
# Note: you may need to restart the kernel to use updated packages.
# scikit-learn has been installed.

# %%
train_sizes = np.linspace(0.01, 0.9, 15)

curves_random_forest = generate_curve_data(data[features], data[target], RandomForestClassifier(), train_sizes)
curves_decision_tree = generate_curve_data(data[features], data[target], DecisionTreeClassifier(), train_sizes)
curves_logistic_regression = generate_curve_data(data[features], data[target], LogisticRegression(), train_sizes)

# %%
plt.plot(train_sizes, curves_random_forest['train_accuracy'], label='Training Accuracy')
plt.plot(train_sizes, curves_random_forest['test_accuracy'], label='Testing Accuracy')
plt.xlabel('Training Set Size')
plt.ylabel('Accuracy')
plt.title('Learning Curve - RandomForest')
plt.legend()
plt.show()

plt.plot(train_sizes, curves_decision_tree['train_accuracy'], label='Training Accuracy')
plt.plot(train_sizes, curves_decision_tree['test_accuracy'], label='Testing Accuracy')
plt.xlabel('Training Set Size')
plt.ylabel('Accuracy')
plt.title('Learning Curve - DecisionClassifier')
plt.legend()
plt.show()

plt.plot(train_sizes, curves_logistic_regression['train_accuracy'], label='Training Accuracy')
plt.plot(train_sizes, curves_logistic_regression['test_accuracy'], label='Testing Accuracy')
plt.xlabel('Training Set Size')
plt.ylabel('Accuracy')
plt.title('Learning Curve - LogisticRegression')
plt.legend()
plt.show()

# %%
plt.plot(train_sizes, curves_random_forest['test_accuracy'], label='Accuracy - RandomForestClassifier')
plt.plot(train_sizes, curves_decision_tree['test_accuracy'], label='Accuracy - DecisionTreeClassifier')
plt.plot(train_sizes, curves_logistic_regression['test_accuracy'], label='Accuracy - LogisticRegression')
plt.xlabel('Training Set Size')
plt.ylabel('Loss cross-entropy')
plt.title('Classifier comparison')
plt.legend()
plt.show()

# %%
plt.plot(train_sizes, curves_random_forest['loss'], label='Loss cross-entropy - RandomForestClassifier')
plt.plot(train_sizes, curves_decision_tree['loss'], label='Loss cross-entropy - DecisionTreeClassifier')
plt.plot(train_sizes, curves_logistic_regression['loss'], label='Loss cross-entropy - LogisticRegression')
plt.xlabel('Training Set Size')
plt.ylabel('Loss cross-entropy')
plt.title('Classifier comparison')
plt.legend()
plt.show()
